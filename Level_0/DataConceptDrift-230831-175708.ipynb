# %% [markdown]
# # Data Drift and Concept Drift Analyses Using Evidently

# %% [markdown]
# ### 1. Importing necessary packages

# %%
# Importing all the relevant libraries
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import LabelEncoder
import evidently

# %% [markdown]
# ### 2. Importing the dataset

# %%
# v1_df(Version 1) is the dataset recorded before drift.
v1_df = pd.read_parquet('/Users/harish/Desktop/Human Acivity Recognition/Data/Drift_data/v1.gzip')
# v2_df(Version 2) is the dataset recorded after drift.
v2_df = pd.read_parquet('/Users/harish/Desktop/Human Acivity Recognition/Data/Drift_data/v2.gzip')
# Print the shape of Version 1 and Version 2
print('Version 1:',v1_df.shape, '\n', 'Version 2:', v2_df.shape)
# Out:
# Version 1: (100000, 563)
#  Version 2: (100000, 563)

# %%
# Checking the Activity distribution of both versions of the dataset.
print (v1_df['Activity'].value_counts(), '\n\n', v2_df['Activity'].value_counts())
# Out:
# LAYING                16762
# WALKING               16728
# WALKING_UPSTAIRS      16675
# STANDING              16645
# WALKING_DOWNSTAIRS    16627
# SITTING               16563
# Name: Activity, dtype: int64
#
#  SITTING               28827
# LAYING                16762
# WALKING_UPSTAIRS      16675
# STANDING              16645
# WALKING_DOWNSTAIRS    16627
# WALKING                4464
# Name: Activity, dtype: int64

# %%
# Label encoding for both V1 and V2 dataset. 
le = LabelEncoder()
v1_df['Activity'] = le.fit_transform(v1_df['Activity'])
v2_df['Activity'] = le.fit_transform(v2_df['Activity'])

# %%
v1_df.rename({'Activity':'target'}, axis =1,inplace = True)
v2_df.rename({'Activity':'target'}, axis =1,inplace = True)

# %% [markdown]
# ### Prediction

# %%
## Load Features and model weight
train_features = joblib.load("/Users/harish/Desktop/Human Acivity Recognition/Notebooks/model_features/K12_train_features.joblib")

model = joblib.load("/Users/harish/Desktop/Human Acivity Recognition/Notebooks/model_registry/K12-tuned-random_forest.joblib")

# %%
v1_test_features = v1_df[train_features]
v1_test_features.columns
# Out:
# Index(['tGravityAcc-energy()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X',
#        'tGravityAcc-min()-X', 'angle(X,gravityMean)', 'tGravityAcc-min()-Y',
#        'tGravityAcc-mean()-Y', 'tGravityAcc-max()-Y', 'angle(Y,gravityMean)',
#        'tBodyAcc-max()-X', 'tGravityAcc-energy()-Y', 'fBodyAcc-entropy()-X'],
#       dtype='object')

# %%
## V1 prediction
v1_test_features = v1_df[train_features]
v1_test_features['prediction'] = model.predict(v1_test_features)
v1_test_features['target'] = v1_df['target']

# %%
v1_test_features.columns
# Out:
# Index(['tGravityAcc-energy()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X',
#        'tGravityAcc-min()-X', 'angle(X,gravityMean)', 'tGravityAcc-min()-Y',
#        'tGravityAcc-mean()-Y', 'tGravityAcc-max()-Y', 'angle(Y,gravityMean)',
#        'tBodyAcc-max()-X', 'tGravityAcc-energy()-Y', 'fBodyAcc-entropy()-X',
#        'prediction', 'target'],
#       dtype='object')

# %%
print(v1_test_features['prediction'].head())
# Out:
# 0    4
# 1    0
# 2    3
# 3    4
# 4    1
# Name: prediction, dtype: int64

# %%
v1_test_features.shape
# Out:
# (100000, 14)

# %%
## V2 prediction
v2_test_features = v2_df[train_features]
v2_test_features['prediction'] = model.predict(v2_test_features)
v2_test_features['target'] = v2_df['target']

# %%
v2_test_features.columns
# Out:
# Index(['tGravityAcc-energy()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X',
#        'tGravityAcc-min()-X', 'angle(X,gravityMean)', 'tGravityAcc-min()-Y',
#        'tGravityAcc-mean()-Y', 'tGravityAcc-max()-Y', 'angle(Y,gravityMean)',
#        'tBodyAcc-max()-X', 'tGravityAcc-energy()-Y', 'fBodyAcc-entropy()-X',
#        'prediction', 'target'],
#       dtype='object')

# %%
v2_test_features.shape
# Out:
# (100000, 14)

# %% [markdown]
# ### There has been a Software update and we have data from both V1 and V2 softwares
#
# #### Let's compare both the data and see of there has been any data drift

# %% [markdown]
# ### Data Drift

# %%
pip install evidently
# Out:
# Requirement already satisfied: evidently in /Users/harish/anaconda3/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: plotly>=5.5.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (5.9.0)
# Requirement already satisfied: rich>=13 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (13.5.2)
# Requirement already satisfied: umap-learn>=0.5.3 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (0.5.3)
# Requirement already satisfied: PyYAML>=5.1 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (6.0)
# Requirement already satisfied: fastapi>=0.98.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (0.101.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (2.28.1)
# Requirement already satisfied: iterative-telemetry==0.0.5 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (0.0.5)
# Requirement already satisfied: pydantic<2,>=1.10 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (1.10.12)
# Requirement already satisfied: scipy>=1.5.4 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (1.10.0)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (0.23.2)
# Requirement already satisfied: scikit-learn>=0.24.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (1.2.1)
# Requirement already satisfied: statsmodels>=0.12.2 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (0.13.5)
# Requirement already satisfied: numpy>=1.19.5 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (1.23.5)
# Requirement already satisfied: typer>=0.9 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (0.9.0)
# Requirement already satisfied: nltk>=3.6.7 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (3.7)
# Requirement already satisfied: pandas>=1.3.5 in /Users/harish/anaconda3/lib/python3.10/site-packages (from evidently) (1.5.3)
# Requirement already satisfied: distro in /Users/harish/anaconda3/lib/python3.10/site-packages (from iterative-telemetry==0.0.5->evidently) (1.8.0)
# Requirement already satisfied: filelock in /Users/harish/anaconda3/lib/python3.10/site-packages (from iterative-telemetry==0.0.5->evidently) (3.9.0)
# Requirement already satisfied: appdirs in /Users/harish/anaconda3/lib/python3.10/site-packages (from iterative-telemetry==0.0.5->evidently) (1.4.4)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from fastapi>=0.98.0->evidently) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from fastapi>=0.98.0->evidently) (4.7.1)
# Requirement already satisfied: click in /Users/harish/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently) (8.0.4)
# Requirement already satisfied: joblib in /Users/harish/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently) (1.1.1)
# Requirement already satisfied: tqdm in /Users/harish/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/harish/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently) (2022.7.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/harish/anaconda3/lib/python3.10/site-packages (from pandas>=1.3.5->evidently) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/harish/anaconda3/lib/python3.10/site-packages (from pandas>=1.3.5->evidently) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from plotly>=5.5.0->evidently) (8.2.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/harish/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->evidently) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/harish/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->evidently) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/harish/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->evidently) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/harish/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->evidently) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from rich>=13->evidently) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from rich>=13->evidently) (3.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.24.0->evidently) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/harish/anaconda3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/harish/anaconda3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently) (22.0)
# Requirement already satisfied: pynndescent>=0.5 in /Users/harish/anaconda3/lib/python3.10/site-packages (from umap-learn>=0.5.3->evidently) (0.5.10)
# Requirement already satisfied: numba>=0.49 in /Users/harish/anaconda3/lib/python3.10/site-packages (from umap-learn>=0.5.3->evidently) (0.56.4)
# Requirement already satisfied: h11>=0.8 in /Users/harish/anaconda3/lib/python3.10/site-packages (from uvicorn>=0.22.0->evidently) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/harish/anaconda3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently) (0.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from numba>=0.49->umap-learn>=0.5.3->evidently) (0.39.1)
# Requirement already satisfied: setuptools in /Users/harish/anaconda3/lib/python3.10/site-packages (from numba>=0.49->umap-learn>=0.5.3->evidently) (65.6.3)
# Requirement already satisfied: six in /Users/harish/anaconda3/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.12.2->evidently) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/harish/anaconda3/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.98.0->evidently) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/harish/anaconda3/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.98.0->evidently) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from evidently.report import Report

from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset
from evidently.test_preset import DataQualityTestPreset
from evidently.metric_preset import TargetDriftPreset, DataQualityPreset
from evidently.metric_preset import DataDriftPreset , ClassificationPreset

# %%
data_drift_report = Report(metrics=[
    DataDriftPreset(),
])
data_drift_report.run(reference_data=v1_test_features, current_data=v1_test_features)

# %%
data_drift_report.save_html("/Users/harish/Desktop/Human Activity Recognition/Notebooks/model_results/drift_report.html")

# %% [markdown]
# ### Data Quality Report

# %%
data_quality_report = Report(metrics=[
    DataQualityPreset(),
])

data_quality_report.run(reference_data=v1_test_features, current_data=v2_test_features)
data_quality_report
# Out:
# /Users/harish/anaconda3/lib/python3.10/site-packages/evidently/metrics/data_integrity/dataset_missing_values_metric.py:165: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_4032daeb4d10495481abae43bbaf4571 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "767ca533-d09d-4494-968a-e91937c796a2", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Dataset Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "", "size": 2, "id": "84c37663-534e-453e-9a68-27697f2bc921", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Metric", "Current", "Reference"], "data": [["id column", "None", "None"], ["target column", "None", "None"], ["prediction column", "prediction", "prediction"], ["date column", "None", "None"], ["number of columns", "14", "14"], ["number of rows", "100000", "100000"], ["missing values", "0", "0"], ["categorical columns", "0", "0"], ["numeric columns", "13", "13"], ["text columns", "0", "0"], ["datetime columns", "0", "0"], ["empty columns", "0", "0"], ["constant columns", "0", "0"], ["almost constant features", "0", "0"], ["duplicated columns", "0", "0"], ["almost duplicated features", "0", "0"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "rich_data", "title": "", "size": 2, "id": "f99aaf20-55b1-43c6-aaf4-99c4377fee1b", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": "Target", "description": "num", "metricsValuesHeaders": ["current", "reference"], "metrics": [{"label": "count", "values": ["100000", "100000"]}, {"label": "mean", "values": ["2.25", "2.5"]}, {"label": "std", "values": ["1.76", "1.71"]}, {"label": "min", "values": ["0.0", "0.0"]}, {"label": "25%", "values": ["1.0", "1.0"]}, {"label": "50%", "values": ["2.0", "3.0"]}, {"label": "75%", "values": ["4.0", "4.0"]}, {"label": "max", "values": ["5.0", "5.0"]}, {"label": "unique", "values": ["6 (0.01%)", "6 (0.01%)"]}, {"label": "most common", "values": ["1.0 (28.83%)", "0.0 (16.76%)"]}, {"label": "missing", "values": ["0 (0.0%)", "0 (0.0%)"]}, {"label": "infinite", "values": ["0 (0.0%)", "0 (0.0%)"]}], "graph": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "x": [0.0, 0.20833333333333334, 0.4166666666666667, 0.625, 0.8333333333333334, 1.0416666666666667, 1.25, 1.4583333333333335, 1.6666666666666667, 1.875, 2.0833333333333335, 2.291666666666667, 2.5, 2.7083333333333335, 2.916666666666667, 3.125, 3.3333333333333335, 3.541666666666667, 3.75, 3.9583333333333335, 4.166666666666667, 4.375, 4.583333333333334, 4.791666666666667], "y": [16762, 0, 0, 0, 28827, 0, 0, 0, 0, 16645, 0, 0, 0, 0, 4464, 0, 0, 0, 0, 16627, 0, 0, 0, 16675], "type": "bar"}, {"marker": {"color": "#ed0400"}, "name": "current", "visible": false, "x": [0.0, 0.027958800173440754, 0.05591760034688151, 0.08387640052032226, 0.11183520069376301, 0.13979400086720378, 0.16775280104064452, 0.19571160121408526, 0.22367040138752603, 0.2516292015609668, 0.27958800173440757, 0.3075468019078483, 0.33550560208128904, 0.3634644022547298, 0.3914232024281705, 0.4193820026016113, 0.44734080277505206, 0.4752996029484928, 0.5032584031219336, 0.5312172032953744, 0.5591760034688151, 0.5871348036422558, 0.6150936038156966, 0.6430524039891373, 0.6710112041625781], "y": [28827, 0, 0, 0, 0, 0, 0, 0, 0, 0, 16645, 0, 0, 0, 0, 0, 0, 4464, 0, 0, 0, 16627, 0, 0, 16675], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "x": [0.0, 0.20833333333333334, 0.4166666666666667, 0.625, 0.8333333333333334, 1.0416666666666667, 1.25, 1.4583333333333335, 1.6666666666666667, 1.875, 2.0833333333333335, 2.291666666666667, 2.5, 2.7083333333333335, 2.916666666666667, 3.125, 3.3333333333333335, 3.541666666666667, 3.75, 3.9583333333333335, 4.166666666666667, 4.375, 4.583333333333334, 4.791666666666667], "y": [16762, 0, 0, 0, 16563, 0, 0, 0, 0, 16645, 0, 0, 0, 0, 16728, 0, 0, 0, 0, 16627, 0, 0, 0, 16675], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "visible": false, "x": [0.0, 0.02795880 ...

# %%
data_quality_report.save_html("/Users/harish/Desktop/Human Activity Recognition/Notebooks/model_results/quality_report.html")

# %% [markdown]
# ### Concept Drift

# %%
num_target_drift_report = Report(metrics=[
    TargetDriftPreset(),
])

num_target_drift_report.run(reference_data=v1_test_features, current_data=v2_test_features)

# %%
num_target_drift_report.save_html("/Users/harish/Desktop/Human Activity Recognition/Notebooks/model_results/concept_drift.html")

# %% [markdown]
# ## Classification Report

# %%
v1_test_features.columns
# Out:
# Index(['tGravityAcc-energy()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X',
#        'tGravityAcc-min()-X', 'angle(X,gravityMean)', 'tGravityAcc-min()-Y',
#        'tGravityAcc-mean()-Y', 'tGravityAcc-max()-Y', 'angle(Y,gravityMean)',
#        'tBodyAcc-max()-X', 'tGravityAcc-energy()-Y', 'fBodyAcc-entropy()-X',
#        'prediction', 'Target'],
#       dtype='object')

# %%
v2_test_features.columns
# Out:
# Index(['tGravityAcc-energy()-X', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X',
#        'tGravityAcc-min()-X', 'angle(X,gravityMean)', 'tGravityAcc-min()-Y',
#        'tGravityAcc-mean()-Y', 'tGravityAcc-max()-Y', 'angle(Y,gravityMean)',
#        'tBodyAcc-max()-X', 'tGravityAcc-energy()-Y', 'fBodyAcc-entropy()-X',
#        'prediction', 'Target'],
#       dtype='object')

# %%
classification_performance_report = Report(metrics=[
    ClassificationPreset(),
])

classification_performance_report.run(reference_data=v1_test_features, current_data=v2_test_features)

classification_performance_report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_d3de4368c759473b8bed4b74821dbbea = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "19234d4a-0d3b-432f-9acd-b1a968436490", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Classification Model Performance. Target: 'target\u2019"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "Current: Model Quality Metrics", "size": 2, "id": "8d0c9013-15c7-4d5d-ada8-7bac50906b86", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "0.777", "label": "Accuracy"}, {"value": "0.767", "label": "Precision"}, {"value": "0.796", "label": "Recall"}, {"value": "0.751", "label": "F1"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "Reference: Model Quality Metrics", "size": 2, "id": "6d807093-4394-487a-9821-38f897431d23", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "0.914", "label": "Accuracy"}, {"value": "0.914", "label": "Precision"}, {"value": "0.914", "label": "Recall"}, {"value": "0.914", "label": "F1"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "68c9d38b-3723-446f-a3e8-7124e37ee6b1", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Class Representation"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "big_graph", "title": "", "size": 2, "id": "f443ea7a-c8c6-491b-a39d-dd91d7c33419", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "showlegend": false, "x": ["1", "0", "5", "2", "4", "3"], "y": [28827, 16762, 16675, 16645, 16627, 4464], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#ed0400"}, "showlegend": false, "x": ["0", "3", "5", "2", "4", "1"], "y": [16762, 16728, 16675, 16645, 16627, 16563], "type": "bar", "xaxis": "x2", "yaxis": "y2"}], "layout": {"template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpet", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "contour": [{"type": "contour", "colo ...

# %%
classification_performance_report.save_html("/Users/harish/Desktop/Human Activity Recognition/Notebooks/model_results/classification_report.html")
